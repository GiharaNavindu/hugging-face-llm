# %%
# %pip install ollama
# Out:
# Defaulting to user installation because normal site-packages is not writeableNote: you may need to restart the kernel to use updated packages.
#
# ...

# %%
import ollama

response = ollama.chat(model="deepseek-r1",
                   messages=[{"role": "user", "content": "Hello, how are you?"}])

print(response)
# Out:
# ---------------------------------------------------------------------------
# ConnectionError                           Traceback (most recent call last)
# Cell In[4], line 3
#       1 import ollama
# ----> 3 response = ollama.chat(model="deepseek-r1",
#       4                    messages=[{"role": "user", "content": "Hello, how are you?"}])
#       6 print(response)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\ollama\_client.py:365, in Client.chat(self, model, messages, tools, stream, think, logprobs, top_logprobs, format, options, keep_alive)
#     318 def chat(
#     319   self,
#     320   model: str = '',
#    (...)
#     330   keep_alive: Optional[Union[float, str]] = None,
#     331 ) -> Union[ChatResponse, Iterator[ChatResponse]]:
#     332   """
#     333   Create a chat response using the requested model.
#     334
#    (...)
#     363   Returns `ChatResponse` if `stream` is `False`, otherwise returns a `ChatResponse` generator.
#     364   """
# ...
