# %%
# %pip install ollama

# %%
import ollama

response = ollama.chat(model="deepseek-r1",
                   messages=[{"role": "user", "content": "Hello, how are you?"}])

print(response)
# Out:
# ---------------------------------------------------------------------------
# ConnectionError                           Traceback (most recent call last)
# /tmp/ipykernel_1928/848803272.py in <cell line: 0>()
#       1 import ollama
#       2
# ----> 3 response = ollama.chat(model="deepseek-r1",
#       4                    messages=[{"role": "user", "content": "Hello, how are you?"}])
#       5
#
# /usr/local/lib/python3.12/dist-packages/ollama/_client.py in chat(self, model, messages, tools, stream, think, logprobs, top_logprobs, format, options, keep_alive)
#     363     Returns `ChatResponse` if `stream` is `False`, otherwise returns a `ChatResponse` generator.
#     364     """
# --> 365     return self._request(
#     366       ChatResponse,
#     367       'POST',
#
# /usr/local/lib/python3.12/dist-packages/ollama/_client.py in _request(self, cls, stream, *args, **kwargs)
#     187       return inner()
#     188
# ...
